# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from PlotTool import *

# %% [markdown]
# # 1 基准

# %%
# 绘制主要结果
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
MEthodNameList = ['LiNGAM','DirectLiNGAM','GES','PC','RESIT','SRIT'] # 文件中对于不同结果的命名

fig = plt.figure(figsize=(16,10)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小
for j in range(6):
    # 计算真假阳性率
    PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegative(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                            '基准',MEthodNameList[j],AllNegtiveNum=(4*5-5)*50 )
    PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1,NegativeRate1 = CalculatePositiveNegative(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                            '2变量变噪声',MEthodNameList[j],AllNegtiveNum=50)
    PositveNumf1Rate3,PositveNumf2Rate3,PositveNumf3Rate3,NegativeRate3 = CalculatePositiveNegative(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                            '10变量变噪声',MEthodNameList[j],AllNegtiveNum=(9*10-10)*50 )

    PlotRate(PositveNumf1Rate,PositveNumf1Rate1,PositveNumf1Rate3,MEthodNameList[j],4,6,0,j) # 绘制第一行 生成的总图是4*6的
    PlotRate(PositveNumf2Rate,PositveNumf2Rate1,PositveNumf2Rate3,MEthodNameList[j],4,6,1,j)
    PlotRate(PositveNumf3Rate,PositveNumf3Rate1,PositveNumf3Rate3,MEthodNameList[j],4,6,2,j)
    PlotRate(NegativeRate,NegativeRate1,NegativeRate3,MEthodNameList[j],4,6,3,j)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-13.5, -0.07, "Noise Rate",fontproperties = 'Times New Roman',fontsize=22)
plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# 绘制函数发现率
# 绘制主要结果
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='2变量变噪声函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='2变量变噪声')
DFCorrectFunctionNum2 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='基准函数发现',header=None)
DFCorrectLinksNum2 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='基准')
DFCorrectFunctionNum3 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='10变量变噪声函数发现',header=None)
DFCorrectLinksNum3 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='10变量变噪声')

fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['SRIT'])
PositveNumf1Rate2,PositveNumf2Rate2,PositveNumf3Rate2 = CalculateFunctionFindRate(DFCorrectFunctionNum2,DFCorrectLinksNum2['SRIT'])
PositveNumf1Rate3,PositveNumf2Rate3,PositveNumf3Rate3 = CalculateFunctionFindRate(DFCorrectFunctionNum3,DFCorrectLinksNum3['SRIT'])

PlotFunctionFindRate(PositveNumf1Rate2,PositveNumf1Rate1,PositveNumf1Rate3,1,3,0,0) # 绘制第一行 生成的总图是4*6的
PlotFunctionFindRate(PositveNumf2Rate2,PositveNumf2Rate1,PositveNumf2Rate3,1,3,0,1)
PlotFunctionFindRate(PositveNumf3Rate2,PositveNumf3Rate1,PositveNumf3Rate3,1,3,0,2)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-4.7, -0.35, "Noise Rate",fontproperties = 'Times New Roman',fontsize=22)
plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=300)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## 1.1 将基准修改为 不同的网络大小

# %%
# 绘制主要结果
# 不同的网络大小
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
MEthodNameList = ['LiNGAM','DirectLiNGAM','GES','PC','RESIT','SRIT'] # 文件中对于不同结果的命名
ReslutsPath = r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx"

fig = plt.figure(figsize=(16,10)) # 绘图的大小
ax = plt.axes()
# plt.style.use('default')

plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小
for j in range(6):
    # 计算真假阳性率
    PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegative(ReslutsPath,'高维数据',MEthodNameList[j])

    PlotRateNumberNodes(PositveNumf1Rate,MEthodNameList[j],4,6,0,j) # 绘制第一行 生成的总图是4*6的
    PlotRateNumberNodes(PositveNumf2Rate,MEthodNameList[j],4,6,1,j)
    PlotRateNumberNodes(PositveNumf3Rate,MEthodNameList[j],4,6,2,j)
    PlotRateNumberNodes(NegativeRate,MEthodNameList[j],4,6,3,j)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-16, -0.07, "Number of Nodes",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
# 绘制函数发现率
# 绘制主要结果
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='高维数据函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='高维数据')


fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
# plt.style.use('default')
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['SRIT'],NumberofCompareType=6)


PlotFunctionFindRateNumberNodes(PositveNumf1Rate1,1,3,0,0)
PlotFunctionFindRateNumberNodes(PositveNumf2Rate1,1,3,0,1)
PlotFunctionFindRateNumberNodes(PositveNumf3Rate1,1,3,0,2)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-6.3, -0.35, "Number of Nodes",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=300)
plt.show()

# %% [markdown]
# # 2 变密度

# %%
# 绘制变密度
# 变密度 使用固定的假阳性率 显然不对 需要在函数中重新计算
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
MEthodNameList = ['LiNGAM','DirectLiNGAM','GES','PC','RESIT','SRIT'] # 文件中对于不同结果的命名

fig = plt.figure(figsize=(16,10)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小
for j in range(6):
    # 计算真假阳性率
    PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegative(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                            '变密度',MEthodNameList[j] )

    PlotRateSI(PositveNumf1Rate,MEthodNameList[j],4,6,0,j) # 绘制第一行 生成的总图是4*6的
    PlotRateSI(PositveNumf2Rate,MEthodNameList[j],4,6,1,j)
    PlotRateSI(PositveNumf3Rate,MEthodNameList[j],4,6,2,j)
    PlotRateSI(NegativeRate,MEthodNameList[j],4,6,3,j)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-10.5, -0.06, "Cross-in-degree",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
# 绘制函数发现率
# 绘制主要结果
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='变密度函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='变密度')


fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['SRIT'])


PlotFunctionFindRateSI(PositveNumf1Rate1,1,3,0,0) # 绘制第一行 生成的总图是4*6的
PlotFunctionFindRateSI(PositveNumf2Rate1,1,3,0,1)
PlotFunctionFindRateSI(PositveNumf3Rate1,1,3,0,2)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-4, -0.35, "Cross-in-degree",fontproperties = 'Times New Roman',fontsize=22)
plt.savefig("High resoltion.png",dpi=300)
plt.show()

# %% [markdown]
# # 3 变样本量

# %%
# 绘制变样本量
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
MEthodNameList = ['LiNGAM','DirectLiNGAM','GES','PC','RESIT','SRIT'] # 文件中对于不同结果的命名

fig = plt.figure(figsize=(16,10)) # 绘图的大小
ax = plt.axes()

# plt.style.use('default')

plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小
for j in range(6):
    # 计算真假阳性率
    PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegative(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                            '变样本量',MEthodNameList[j],NumberofCompareType=4)

    PlotRateSI(PositveNumf1Rate,MEthodNameList[j],4,6,0,j,NumberofCompareType=4) # 绘制第一行 生成的总图是4*6的
    PlotRateSI(PositveNumf2Rate,MEthodNameList[j],4,6,1,j,NumberofCompareType=4)
    PlotRateSI(PositveNumf3Rate,MEthodNameList[j],4,6,2,j,NumberofCompareType=4)
    PlotRateSI(NegativeRate,MEthodNameList[j],4,6,3,j,NumberofCompareType=4)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-10, -0.06, "Sample Size",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
# 绘制函数发现率
# 绘制主要结果
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='变样本量函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='变样本量')


fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['SRIT'],NumberofCompareType=4)


PlotFunctionFindRateSI(PositveNumf1Rate1,1,3,0,0) # 绘制第一行 生成的总图是4*6的
PlotFunctionFindRateSI(PositveNumf2Rate1,1,3,0,1)
PlotFunctionFindRateSI(PositveNumf3Rate1,1,3,0,2)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-3.5, -0.35, "Sample Size",fontproperties = 'Times New Roman',fontsize=22)
plt.savefig("High resoltion.png",dpi=300)
plt.show()

# %% [markdown]
# # 4 变噪声水平

# %%
# 绘制主要结果
# 不同的网络大小
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
MEthodNameList = ['LiNGAM','DirectLiNGAM','GES','PC','RESIT','SRIT'] # 文件中对于不同结果的命名
ReslutsPath = r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx"

fig = plt.figure(figsize=(20,10)) # 绘图的大小
ax = plt.axes()
# plt.style.use('default')

plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小
for j in range(6):
    # 计算真假阳性率
    PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegative(ReslutsPath,'变噪声',MEthodNameList[j])

    PlotRateNumberNodes(PositveNumf1Rate,MEthodNameList[j],4,6,0,j) # 绘制第一行 生成的总图是4*6的
    PlotRateNumberNodes(PositveNumf2Rate,MEthodNameList[j],4,6,1,j)
    PlotRateNumberNodes(PositveNumf3Rate,MEthodNameList[j],4,6,2,j)
    PlotRateNumberNodes(NegativeRate,MEthodNameList[j],4,6,3,j)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-20, -0.07, "Noise Level",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
# 绘制函数发现率
# 绘制主要结果
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='变噪声函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='变噪声')


fig = plt.figure(figsize=(10,2)) # 绘图的大小
ax = plt.axes()
# plt.style.use('default')
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['SRIT'])


PlotFunctionFindRateNumberNodes(PositveNumf1Rate1,1,3,0,0)
PlotFunctionFindRateNumberNodes(PositveNumf2Rate1,1,3,0,1)
PlotFunctionFindRateNumberNodes(PositveNumf3Rate1,1,3,0,2)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-6.5, -0.35, "Noise Level",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=300)
plt.show()

# %% [markdown]
# # 5 弱因果联系

# %%
# 绘制弱因果联系
# 只有一个方法 没有方法的对比
from PlotTool import *
MEthodNameList = ['LiNGAM','DirectLiNGAM','GES','PC','RESIT','SRIT'] # 文件中对于不同结果的命名

NumberofCompareType = 5

fig = plt.figure(figsize=(16,10)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小

# 计算真假阳性率
for j in range(6):
    # 计算真假阳性率
    PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegative(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                            '弱因果联系',MEthodNameList[j],NumberofCompareType)

    PlotRateSI(PositveNumf1Rate,MEthodNameList[j],4,6,0,j,NumberofCompareType) # 绘制第一行 生成的总图是4*6的
    PlotRateSI(PositveNumf2Rate,MEthodNameList[j],4,6,1,j,NumberofCompareType)
    PlotRateSI(PositveNumf3Rate,MEthodNameList[j],4,6,2,j,NumberofCompareType)
    PlotRateSI(NegativeRate,MEthodNameList[j],4,6,3,j,NumberofCompareType)


# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-15, -0.06, "Different Coefficients",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
from PlotTool import *
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='弱因果函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='弱因果联系')
NumberofCompareType = 5

fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['weak'],NumberofCompareType)


PlotFunctionFindRateOnlySRIT(PositveNumf1Rate1,1,3,0,0,NumberofCompareType) # 绘制第一行 生成的总图是4*6的
PlotFunctionFindRateOnlySRIT(PositveNumf2Rate1,1,3,0,1,NumberofCompareType)
PlotFunctionFindRateOnlySRIT(PositveNumf3Rate1,1,3,0,2,NumberofCompareType)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-6, -0.35, "Different Coefficients",fontproperties = 'Times New Roman',fontsize=22)
plt.savefig("High resoltion.png",dpi=300)
plt.show()

# %% [markdown]
# # 6 不同显著性水平

# %%
# 绘制不同显著性水平
# 只有一个方法 没有方法的对比
from PlotTool import *

TestName = 'Thereshold'
NumberofCompareType = 5

fig = plt.figure(figsize=(16,4)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小

# 计算真假阳性率
PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegativeOnlySRIT(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                        '不同显著性水平',TestName,NumberofCompareType)

PlotRateOnlySRIT(PositveNumf1Rate,1,4,0,0,NumberofCompareType) # 绘制第一行 生成的总图是4*6的
PlotRateOnlySRIT(PositveNumf2Rate,1,4,0,1,NumberofCompareType)
PlotRateOnlySRIT(PositveNumf3Rate,1,4,0,2,NumberofCompareType)
PlotRateOnlySRIT(NegativeRate,1,4,0,3,NumberofCompareType)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-8.5, -0.03, "Different P-Threshold",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
from PlotTool import *
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='不同显著水平函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='不同显著性水平')
NumberofCompareType = 5

fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['Thereshold'],NumberofCompareType)


PlotFunctionFindRateOnlySRIT(PositveNumf1Rate1,1,3,0,0,NumberofCompareType) # 绘制第一行 生成的总图是4*6的
PlotFunctionFindRateOnlySRIT(PositveNumf2Rate1,1,3,0,1,NumberofCompareType)
PlotFunctionFindRateOnlySRIT(PositveNumf3Rate1,1,3,0,2,NumberofCompareType)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-6, -0.35, "Different P-Threshold",fontproperties = 'Times New Roman',fontsize=22)
plt.savefig("High resoltion.png",dpi=300)
plt.show()

# %%
PositveNumf1Rate1.shape
# Out:
# (10, 5)

# %% [markdown]
# # 7 更复杂的函数关系

# %%
from PlotTool import *
TestName = 'log'
NumberofCompareType = 6

fig = plt.figure(figsize=(20,4)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小

# 绘制关系发现率
PositveNumf1Rate,PositveNumf2Rate,NegativeRate = CalculatePositiveNegativeVariousFunction(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                        '不同函数形式',TestName,NumberofCompareType)

PlotRateVariousFunction(PositveNumf1Rate,1,4,0,0,NumberofCompareType) 
PlotRateVariousFunction(PositveNumf2Rate,1,4,0,1,NumberofCompareType)
PlotRateVariousFunction(NegativeRate,1,4,0,2,NumberofCompareType)

# 绘制模型重建率
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='不同函数形式函数发现')
PositveNumf1Rate1,PositveNumf2Rate1 = \
    CalculateFunctionvariousFunction(DFCorrectFunctionNum1,TestName)
All = np.hstack((PositveNumf1Rate1,PositveNumf2Rate1))
PlotFunctionFindRateVariousFunction(All,1,4,0,3,NumberofCompareType=2) # 此处的2表示只有两种函数关系


# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-3.5, -0.3, "Methods",fontproperties = 'Times New Roman',fontsize=22)
plt.text(1, -0.3, "Function From",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
# 所有的函数形式
from PlotTool import *
NumberofCompareType = 6

fig = plt.figure(figsize=(20,8)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小

# 绘制关系发现率
PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,\
        PositveNumf4Rate,PositveNumf5Rate,PositveNumf6Rate,PositveNumf7Rate,NegativeRate = \
        CalculatePositiveNegativeAllFunction(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                '包含所有函数形式',TestName,NumberofCompareType)

PlotRateallFunction(PositveNumf1Rate,2,4,0,0,NumberofCompareType) 
PlotRateallFunction(PositveNumf2Rate,2,4,0,1,NumberofCompareType)
PlotRateallFunction(PositveNumf3Rate,2,4,0,2,NumberofCompareType)
PlotRateallFunction(PositveNumf4Rate,2,4,0,3,NumberofCompareType)
PlotRateallFunction(PositveNumf5Rate,2,4,1,0,NumberofCompareType)
PlotRateallFunction(PositveNumf6Rate,2,4,1,1,NumberofCompareType)
PlotRateallFunction(PositveNumf7Rate,2,4,1,2,NumberofCompareType)
PlotRateallFunction(NegativeRate,2,4,1,3,NumberofCompareType)

# 绘制模型重建率
# DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='不同函数形式函数发现')
# PositveNumf1Rate1,PositveNumf2Rate1 = \
#     CalculateFunctionvariousFunction(DFCorrectFunctionNum1,TestName)
# All = np.hstack((PositveNumf1Rate1,PositveNumf2Rate1))
# PlotFunctionFindRateVariousFunction(All,1,4,0,3,NumberofCompareType=2) # 此处的2表示只有两种函数关系


# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-8.3, -0.07, "Methods",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
# 函数发现率
from PlotTool import *

fig = plt.figure(figsize=(4,4)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小

# 绘制模型重建率
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",\
                                      sheet_name='包含所有函数形式函数发现')

PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,\
        PositveNumf4Rate,PositveNumf5Rate,PositveNumf6Rate,PositveNumf7Rate = \
            CalculateFunctionAllFunction(DFCorrectFunctionNum1,TestName='all')

All = np.hstack((PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,\
        PositveNumf4Rate,PositveNumf5Rate,PositveNumf6Rate,PositveNumf7Rate))
PlotFunctionFindRateVariousFunction(All,1,1,0,0,NumberofCompareType=7) # 此处的2表示只有两种函数关系


# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴

plt.text(2.1, -0.25, "Function From",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %% [markdown]
# # 8 不同运行时间

# %%
# 绘制不同显著性水平
# 只有一个方法 没有方法的对比
from PlotTool import *

TestName = 'RunTime'
NumberofCompareType = 5

fig = plt.figure(figsize=(16,4)) # 绘图的大小
# plt.style.use('default')
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小

# 计算真假阳性率
PositveNumf1Rate,PositveNumf2Rate,PositveNumf3Rate,NegativeRate = CalculatePositiveNegativeOnlySRIT(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",
                                                                                        '不同运行时长',TestName,NumberofCompareType)

PlotRateOnlySRIT(PositveNumf1Rate,1,4,0,0,NumberofCompareType) # 绘制第一行 生成的总图是4*6的
PlotRateOnlySRIT(PositveNumf2Rate,1,4,0,1,NumberofCompareType)
PlotRateOnlySRIT(PositveNumf3Rate,1,4,0,2,NumberofCompareType)
PlotRateOnlySRIT(NegativeRate,1,4,0,3,NumberofCompareType)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-9.4, -0.03, "Different Maximum Runtime (s)",fontproperties = 'Times New Roman',fontsize=22)
# plt.legend(loc="lower right",fontsize=6)
plt.savefig("High resoltion.png",dpi=600)
plt.show()

# %%
from PlotTool import *
# MEthodNameList = ['DirectLiNGAM','RESIT','GES','pc','LiNGAM','PCMCI+','sr']
DFCorrectFunctionNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='不同运行时长函数发现',header=None)
DFCorrectLinksNum1 = pd.read_excel(r"D:\工作\函数因果模型1121\各部分\实验结果总结.xlsx",sheet_name='不同运行时长')
NumberofCompareType = 5

fig = plt.figure(figsize=(8,2)) # 绘图的大小
ax = plt.axes()
plt.rcParams['xtick.direction'] = 'in' # 设置刻度向内
plt.rcParams['ytick.direction'] = 'in' # 设置刻度向内
plt.rcParams['boxplot.flierprops.markersize'] = 3 # 设置离群点大小


PositveNumf1Rate1,PositveNumf2Rate1,PositveNumf3Rate1 = CalculateFunctionFindRate(DFCorrectFunctionNum1,DFCorrectLinksNum1['RunTime'],NumberofCompareType)


PlotFunctionFindRateOnlySRIT(PositveNumf1Rate1,1,3,0,0,NumberofCompareType) # 绘制第一行 生成的总图是4*6的
PlotFunctionFindRateOnlySRIT(PositveNumf2Rate1,1,3,0,1,NumberofCompareType)
PlotFunctionFindRateOnlySRIT(PositveNumf3Rate1,1,3,0,2,NumberofCompareType)

# 调整子图之间的距离 wspace是水平距离 hspace是垂直距离
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2) 
# 添加文字 -10 x轴, -0.07 y轴
plt.text(-8, -0.35, "Different Maximum Runtime (s)",fontproperties = 'Times New Roman',fontsize=22)
plt.savefig("High resoltion.png",dpi=300)
plt.show()
